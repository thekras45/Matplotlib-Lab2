# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Q1: Import matplotlib library

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # Q2: Create a one line chart using two arrays. The first array represents x and the second array represents y
# | x     |     y    |
# | ----- | -------- |
# | 1    | 1       |
# | 2    | 2       |
# | 3    | 3       |
# | 4    | 5       |
# | 5    | 8       |
# | 6    | 13      |
# | 7    | 20      |

# %%
x = [1,2,3,4,5,6,7]
y = [1,2,3,5,8,13,20]
plt.plot(x,y)

# %% [markdown]
# # Q3: Create a two lines chart using the same previous arrays.
# But this time:
# - Mark each point with a circle.
# - Use dashed lines.
# - Set the size of the marker (circle) to size 10.
# - Set the width of the line to 3.
# - Add legends. 'Normal' for array x and 'Fast' for array y.

# %%
plt.plot(x, y, 'o',markersize=10)#with a circle.
plt.plot(x, y, '-.',linewidth=10)#with dashed lines
plt.legend(['x','y'], shadow = True, loc = 0) # location (0 = best)
plt.xlabel('Normal')
plt.ylabel('Fast')
plt.show()

# %% [markdown]
# # Q4: Display multiple linear charts in one row using the charts given below.
# - Give each chart a title
# - Add a super title 'my data visulaization assignment'.

# %%
title='my data visulaization assignment'

#title = First Chart
x_plot1 = np.array([1, 2, 3, 4, 5, 6, 7])
y_plot1 = np.array([1, 1, 2, 3, 5, 8, 13])

#title = Second Chart
x_plot2 = np.array([0, 1, 2, 3, 4, 5, 6])
y_plot2 = np.array([2, 4, 6, 8, 10, 12, 14])

#title = Third Chart
x_plot3 = np.array([0, 1, 3, 4])
y_plot3 = np.array([4, 6, 3, 4])

# %%
plt .figure(figsize=(10,6))
plt.suptitle(title,size=20)

plt.subplot(1,3,1)
plt.title('First Chart')
plt.plot(x_plot1,y_plot1)
plt.fill_between(x_plot1,y_plot1, color ='r')

plt.subplot(1,3,2)
plt.title('Second Chart')
plt.plot(x_plot2,y_plot2)


plt.subplot(1,3,3)
plt.title('Third Chart')
plt.plot(x_plot3,y_plot3)

# %% [markdown]
# # Q5: Define an array that has a values of your top three TV series and define another array to hold the rating of the three TV series out of 10. Create a bar chart using the two arrays
# - Set a new color for the bars.
# - Change the width of the bars to width 0.5.

# %%
#df = pd.read_csv('tmdb-movies.csv')
top_movies = ['Titanic','The Avengers','Star Wars: The Force Awakens']
reating = [13.4 , 11.9 , 7.5]
plt.bar(top_movies, reating, color= 'r' , linewidth = 0.5)
# Out:
# <BarContainer object of 3 artists>

# %% [markdown]
# # Q6: Create a scatter plot  using two arrays. The first array represents carAge and the second array represents carSpeed, set a specific color for each dot by using an array of different colors and add labels for the plot
# | carAge | carSpeed |
# | ----- | -------- |
# | 5    | 99       |
# | 7    | 86       |
# | 8    |87      |
# | 7    | 88       |
# | 2    | 111       |
# | 17    | 86       |
# | 2    | 103      |
# | 9    | 87       |
# | 4    | 94       |
# | 11    | 78      |

# %% [markdown]
# - Set a new color for each dot by using an array of different colors.
# - Change the size of the dots to size 350.
# - Add labels for x-axis and y-axis.
# - Adjust the transparency of the dots with the alpha argument. let the alpha value be 0.4

# %%
carAge=[5,7,8,7,2,17,2,9,4,11]
carSpeed=[99,86,87,88,111,86,103,87,94,78]
plt.scatter(carAge,carSpeed ,c =np.random.rand(len(carAge),3), marker='.' ,s=350,  alpha=0.4 ,)
plt.xlabel('X')
plt.ylabel('Y')
# Out:
# Text(0, 0.5, 'Y')

# %% [markdown]
# # Q7: Create a pie chart using two arrays. The first array represents python_libraries and the second array represents your skills out of 10 at each library
# | python_libraries |
# | ------------ |
# | NumPy        |
# | Pandas       |
# | Matplotlib   |
# | Seaborn      |
# | Plotly       |
# | Scikit-learn |

# %% [markdown]
# - Set a new color for each wedge by using an array of different colors.
# - Pull your favorite library wedge 0.3 from the center of the pie.
# - Add a shadow to the pie chart

# %%
df = pd.DataFrame({ 'python_libraries' : ['NumPy','Pandas','Matplotlib', 'Seaborn','Plotly','Scikit-learn' ],
                  'skills' : [20 , 10 , 14, 12 ,16 , 9]})
co = np.arange(0, len(df))
plt.pie(df['skills'], labels = df['python_libraries'], explode = [0.3 , 0.3 , 0 , 0.3 , 0 ,0], shadow = True )
# Out:
# ([<matplotlib.patches.Wedge at 0x7f82f30a5cd0>,
#   <matplotlib.patches.Wedge at 0x7f82f30af3d0>,
#   <matplotlib.patches.Wedge at 0x7f82f30afa30>,
#   <matplotlib.patches.Wedge at 0x7f82f2f121c0>,
#   <matplotlib.patches.Wedge at 0x7f82f2f12910>,
#   <matplotlib.patches.Wedge at 0x7f82f2f0a0a0>],
#  [Text(0.9995016227154593, 0.980304292650585, 'NumPy'),
#   Text(-0.504248833596969, 1.3060371793391246, 'Pandas'),
#   Text(-1.0597079727854988, 0.2949898513760238, 'Matplotlib'),
#   Text(-1.0367615911658519, -0.9408110347371843, 'Seaborn'),
#   Text(0.2743852978648386, -1.0652289464315283, 'Plotly'),
#   Text(1.0336618994982714, -0.3762221119573192, 'Scikit-learn')])

# %% [markdown]
# # Q8: Create a histogram with 250 values and 15 bars

# %%
plt.hist(np.random.randint(500, size=250),15,rwidth=0.7)
# Out:
# (array([19., 15., 17., 11., 16., 20., 17., 17., 17., 19., 10., 21., 20.,
#         17., 14.]),
#  array([  1. ,  34.2,  67.4, 100.6, 133.8, 167. , 200.2, 233.4, 266.6,
#         299.8, 333. , 366.2, 399.4, 432.6, 465.8, 499. ]),
#  <BarContainer object of 15 artists>)
